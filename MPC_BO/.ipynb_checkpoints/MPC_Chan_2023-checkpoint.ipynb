# %% [markdown]
# #### System and data taken from [Chan et. al 2023](https://ieeexplore.ieee.org/document/10156650/)

# %%
import numpy as np
import matplotlib.pyplot as plt
from casadi import *
from copy import *
import scipy.io

# %% [markdown]
# ### Loading in information

# %%
#model = scipy.io.loadmat('data/APPJmodel_2021_06_08_15h57m55s_n4sid_alldata.mat')
model = scipy.io.loadmat('data/mat/subspace_id.mat') # 5 state model 

Np = 10 # prediction horizon
Ns = 60 # simulation horizon
ts = 0.5 # sampling time
Tref = 43.0 # reference temperature
Tmax = 45.0 # max temp. for patient comfort
Kcem = 0.5

# %%
# state, input, state-transition, and observation matrices
A, B, C = model['A'], model['B'], model['C']
nx, nu, ny, nyc = A.shape[0], B.shape[1], C.shape[0], 1

yss = np.ravel(model['yss']) # use to center data for controller [Ts, I]
uss = np.ravel(model['uss']) # use to center data for controller [P, q]

# constraint bounds, centered about ss
u_min = np.array([1.5, 3.5]) - uss
u_max = np.array([3.5, 7.5]) - uss
y_min = np.array([25, 0]) - yss
y_max = np.array([Tmax, 80]) - yss

# just assume that the values begin at equilibrium
u_init = np.zeros(nu)
y_init = np.zeros(ny)
x_init = np.zeros(nx) 

# covariance process noise, covariance observation noise, 
# initial covariance matrix, initial estimated state
Qw = np.random.normal(loc=0.0, scale=1.0, size=(nx, nx))
Rv = np.random.normal(loc=0.0, scale=10E-3, size=(nu, nu)) # suggestion by Ali
P_init = np.random.normal(loc=0.0, scale=1.0, size=(nx, nx))
xhat_init = np.zeros(nx)

# %% [markdown]
# ### Set up controller

# %%
opti = Opti() 

x = SX.sym('x', nx)
u = SX.sym('u', nu)
y = SX.sym('y', ny)

# Linearized equations based on deviation values centered around ss
f = Function('f', [x, u], [A@x + B@u])
h = Function('h', [x], [C@x])

# nonlinear CEM requires absolute Ts 
lstg = (Kcem ** (Tref - (y[0] + yss[0])) ) * ts / 60
lstage = Function('lstage', [y], [lstg])
CEM = ( Kcem ** (Tref - (y[0] + yss[0])) ) * ts / 60
CEMadd = Function('CEMadd', [y], [CEM])

# containers
X = [0 for _ in range(Np + 1)]
U = [0 for _ in range(Np)]
Y = [0 for _ in range(Np + 1)]
J = 0

CEMref = opti.parameter(nyc) # target/reference output, fixed during optimization
opti.set_value(CEMref, np.zeros(nyc)) # set value of parameter
CEM0 = opti.parameter(nyc) # initial CEM 
opti.set_value(CEM0, np.zeros(nyc)) # set value of initial CEM parameter

X[0] = opti.parameter(nx) # initial state as parameter
opti.set_value(X[0], np.zeros(nx)) # set value of initial state parameter
Y[0] = opti.variable(ny) # output as decision variable 
opti.subject_to(Y[0] == h(X[0])) # define output constraints based on initial state
opti.set_initial(Y[0], y_init) # define initial output 

for k in range(Np): 
    # controller @ k
    U[k] = opti.variable(nu) # controller input as decision variable
    opti.subject_to(opti.bounded(u_min, U[k], u_max)) # define controller input constraints
    opti.set_initial(U[k], u_init) # define initial controller input

    # increment stage cost 
    Jstage = lstage(Y[k])
    J += Jstage

    # state @ k+1
    X[k + 1] = opti.variable(nx) # state at k+1 as decision variable
    # opti.subject_to(opti.bounded(y_min, X[k + 1], y_max)) # define state constraints
    opti.set_initial(X[k + 1], x_init) # define initial state 

    # output @ k+1
    Y[k + 1] = opti.variable(ny) # output at k+1 as decision variable
    opti.subject_to(opti.bounded(y_min, Y[k + 1], y_max)) # define output constraints
    opti.set_initial(Y[k + 1], y_init) # define initial output

    # dynamics constraint
    opti.subject_to(X[k + 1] == f(X[k], U[k]))
    # output equality constraint
    opti.subject_to(Y[k + 1] == h(X[k + 1]))

# calculate the terminal cost, note no splits or iterations
J += lstage(Y[-1])
J = (CEMref - (J + CEM0)) ** 2 # eq. 6 control objective 

# minimize cost
opti.minimize(J)

p_opts = {'verbose': False, 'expand': True, 'print_time': 1} # options taken from K.C. --> Ipopt options to print to console
s_opts = {'max_iter': 1000, 'print_level': 1, 'tol': 1e-6}

opti.solver('ipopt', p_opts, s_opts)

soln = opti.solve()
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 265.00us ( 24.09us)  16.19us (  1.47us)        11
#        nlp_g  | 670.00us ( 60.91us)  38.81us (  3.53us)        11
#   nlp_grad_f  | 581.00us ( 48.42us)  36.14us (  3.01us)        12
#   nlp_hess_l  | 379.00us ( 37.90us)  22.97us (  2.30us)        10
#    nlp_jac_g  | 693.00us ( 57.75us)  43.38us (  3.62us)        12
#        total  | 166.08ms (166.08ms)  10.37ms ( 10.37ms)         1

# %% [markdown]
# #### Validate the KF implementation by running an open-loop sim
#
# We are trying to compare the plants measurements to the estimated states output by the KF

# %%
# containers
X_plant = np.zeros((nx, Np + 1)) 
Y_plant = np.zeros((ny, Np + 1))

X_est = np.zeros((nx, Np + 1))
P_est = np.zeros((Np + 1, nx, nx))

# %%
# @ k = 0
# get U inputs from running controller once
U_kf_test = np.asarray([soln.value(u) for u in U]).reshape(-1, nu).T

# initialize the plant state
X_plant[:, 0] = np.ravel(x_init)

# run plant @ k=0, get the first observable result and corrupt with noise
Y_plant[:, 0] = np.ravel((h(X_plant[:, 0])).full())
Y_plant[:, 0][0] += np.random.normal(loc=0., scale=10E-3)
Y_plant[:, 0][1] += np.random.normal(loc=0., scale=10E-3)

# initialize KF
X_est[:, 0] = np.zeros(nx)
P_est[0] = P_init

for k in range(Np):
    
    # --- KALMAN FILTER ---
    # A priori estimate, prediction
    xphat = A @ X_est[:, k] + B @ U_kf_test[:, k] # xhat{k+1, k}
    Pphat = A @ P_est[k] @ np.transpose(A) + Qw # Pphat{k+1, k}

    # Measurement update, correction
    # * Compute Kalman gain
    yr = Y_plant[:, k] - (C @ xphat) # Measurement pre-fit residual
    Sk = C @ Pphat @ np.transpose(C) + Rv # Innovation/pre-fit residual covariance
    Kk = Pphat @ np.transpose(C) @ inv(Sk) # Optimal Kalman gain
    # * Update estimate with measurement and uncertainty
    xhat = xphat + Kk @ yr
    Phat = np.identity(A.shape[0]) - Kk @ C @ Pphat
    
    # storage kalman filter states
    X_est[:, k + 1] = np.ravel(xhat)
    P_est[k + 1] = Phat
    # ----------------------

    # run the plant again
    X_plant[:, k + 1] = np.ravel(f(X_plant[:, k], U_kf_test[:, k]).full())
    
    # obtain the y output, corrupt it with 0-mean noise
    Y_plant[:, k + 1] = np.ravel(h(X_plant[:, k]).full())
    Y_plant[:, k + 1][0] += np.random.normal(loc=0., scale=10E-3)
    Y_plant[:, k + 1][1] += np.random.normal(loc=0., scale=10E-3)

xp_axis = np.arange(Np + 1)
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, figsize=(7, 15))   

# State 1
ax1.plot(xp_axis, np.ravel(X_plant[0]) + yss[0], label='Actual')
ax1.plot(xp_axis, np.ravel(X_est[0]) + yss[0], label='Est.')
ax1.set_ylabel('Surface temperature [$^\circ$C]')
ax1.legend(loc='lower right')

# State 2
ax3.plot(xp_axis, np.ravel(X_plant[2]) + yss[1], label='Actual')
ax3.plot(xp_axis, np.ravel(X_est[2]) + yss[1], label='Est.')
ax3.set_ylabel('Intensity I [a.u.]')
ax3.legend()

ax2.plot(xp_axis, np.ravel(X_plant[1]), label='actual')
ax2.plot(xp_axis, np.ravel(X_est[1]), label='est.')
ax2.set_ylabel('')

ax4.plot(xp_axis, np.ravel(X_plant[3]), label='actual')
ax4.plot(xp_axis, np.ravel(X_est[3]), label='est.')
ax4.set_ylabel('')

ax5.plot(xp_axis, np.ravel(X_plant[4]), label='actual')
ax5.plot(xp_axis, np.ravel(X_est[4]), label='est.')
ax5.set_ylabel('')

ax5.set_xlabel('Time [s]')
plt.tight_layout()

# %% [markdown]
# ### Run closed-loop simulation with Kalman filter

# %%
U_sim = np.zeros((nu, Ns))
X_sim = np.zeros((nx, Ns + 1))
Y_sim = np.zeros((ny, Ns + 1))
CEMsim = np.zeros((nyc, Ns + 1))
X_est = np.zeros((nx, Ns + 1))
P_est = np.zeros((Ns + 1, nx, nx))

X_sim[:, 0] = np.ravel(x_init) 

Y_sim[:, 0] = np.ravel(h(X_sim[:, 0]).full())
Y_sim[:, 0][0] += np.random.normal(loc=0., scale=10E-3)
Y_sim[:, 0][1] += np.random.normal(loc=0., scale=10E-3)

CEMsim[:, 0] = np.zeros((nyc,))

X_est[:, 0] = np.zeros(nx)
P_est[0] = P_init

# %%
# run closed-loop
for k in range(Ns):    
    opti.set_value(X[0], X_sim[:, k]) # set initial state parameters 
    #CEMref and CEM0
    opti.set_value(CEMref, 1.5)
    
    opti.set_value(CEM0, CEMsim[:, k])
    sol = opti.solve() # solve using the controller
    U_soln = np.asarray([sol.value(u) for u in U]).reshape(nu, -1) # extract control inputs based on state

    U_sim[:, k] = U_soln[:, 0] # for control, only interested in the first opt. control input
    
    # --- KALMAN FILTER ---
    # A priori estimate, prediction
    xphat = A @ X_est[:, k] + B @ U_sim[:, k] # xhat{k+1, k}
    Pphat = A @ P_est[k] @ np.transpose(A) + Qw # Pphat{k+1, k}

    # Measurement update, correction
    # * Compute Kalman gain
    yr = Y_sim[:, k] - (C @ xphat) # Measurement pre-fit residual
    Sk = C @ Pphat @ np.transpose(C) + Rv # Innovation/pre-fit residual covariance
    Kk = Pphat @ np.transpose(C) @ inv(Sk) # Optimal Kalman gain
    # * Update estimate with measurement and uncertainty
    xhat = xphat + Kk @ yr
    Phat = np.identity(A.shape[0]) - Kk @ C @ Pphat
    
    # store kalman filter states
    X_est[:, k + 1] = np.ravel(xhat)
    P_est[k + 1] = Phat
    # ----------------------
    
    X_sim[:, k + 1] = np.ravel(f(X_sim[:, k], U_sim[:, k]).full()) # apply input to state system/plant
    Y_sim[:, k + 1] = np.ravel(h(X_sim[:, k + 1]).full()) # apply input to output system/plant
    Y_sim[:, k + 1][0] += np.random.normal(loc=0., scale=10E-3)
    Y_sim[:, k + 1][1] += np.random.normal(loc=0., scale=10E-3)
    
    CEMsim[:, k + 1] = CEMsim[:, k] + np.ravel(CEMadd(Y_sim[:, k + 1]).full())
# Out:
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 275.00us ( 15.28us)  24.79us (  1.38us)        18
#        nlp_g  | 702.00us ( 39.00us)  64.18us (  3.57us)        18
#     nlp_grad  |  91.00us ( 91.00us)   5.67us (  5.67us)         1
#   nlp_grad_f  | 595.00us ( 29.75us)  49.22us (  2.46us)        20
#   nlp_hess_l  | 429.00us ( 26.81us)  36.27us (  2.27us)        16
#    nlp_jac_g  | 714.00us ( 35.70us)  66.70us (  3.33us)        20
#        total  |   4.86ms (  4.86ms)   4.84ms (  4.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 286.00us ( 10.59us)  33.49us (  1.24us)        27
#        nlp_g  | 735.00us ( 27.22us)  89.89us (  3.33us)        27
#     nlp_grad  |  97.00us ( 48.50us)  11.10us (  5.55us)         2
#   nlp_grad_f  | 606.00us ( 20.20us)  60.91us (  2.03us)        30
#   nlp_hess_l  | 444.00us ( 18.50us)  50.31us (  2.10us)        24
#    nlp_jac_g  | 740.00us ( 24.67us)  91.58us (  3.05us)        30
#        total  |   5.32ms (  5.32ms)   5.30ms (  5.30ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 296.00us (  8.22us)  41.55us (  1.15us)        36
#        nlp_g  | 763.00us ( 21.19us) 114.09us (  3.17us)        36
#     nlp_grad  | 102.00us ( 34.00us)  16.05us (  5.35us)         3
#   nlp_grad_f  | 619.00us ( 15.48us)  72.60us (  1.81us)        40
#   nlp_hess_l  | 460.00us ( 14.38us)  63.64us (  1.99us)        32
#    nlp_jac_g  | 763.00us ( 19.08us) 116.15us (  2.90us)        40
#        total  |   5.03ms (  5.03ms)   5.02ms (  5.02ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 304.00us (  6.76us)  49.78us (  1.11us)        45
#        nlp_g  | 792.00us ( 17.60us) 137.64us (  3.06us)        45
#     nlp_grad  | 107.00us ( 26.75us)  21.04us (  5.26us)         4
#   nlp_grad_f  | 633.00us ( 12.66us)  84.03us (  1.68us)        50
#   nlp_hess_l  | 475.00us ( 11.88us)  76.90us (  1.92us)        40
#    nlp_jac_g  | 785.00us ( 15.70us) 139.78us (  2.80us)        50
#        total  |   5.00ms (  5.00ms)   4.98ms (  4.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 315.00us (  5.83us)  58.66us (  1.09us)        54
#        nlp_g  | 823.00us ( 15.24us) 161.86us (  3.00us)        54
#     nlp_grad  | 112.00us ( 22.40us)  26.34us (  5.27us)         5
#   nlp_grad_f  | 647.00us ( 10.78us)  96.28us (  1.60us)        60
#   nlp_hess_l  | 491.00us ( 10.23us)  90.99us (  1.90us)        48
#    nlp_jac_g  | 810.00us ( 13.50us) 164.58us (  2.74us)        60
#        total  |   5.35ms (  5.35ms)   5.25ms (  5.25ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 325.00us (  5.16us)  67.29us (  1.07us)        63
#        nlp_g  | 852.00us ( 13.52us) 185.08us (  2.94us)        63
#     nlp_grad  | 116.00us ( 19.33us)  30.82us (  5.14us)         6
#   nlp_grad_f  | 661.00us (  9.44us) 107.68us (  1.54us)        70
#   nlp_hess_l  | 507.00us (  9.05us) 104.13us (  1.86us)        56
#    nlp_jac_g  | 835.00us ( 11.93us) 188.06us (  2.69us)        70
#        total  |   4.94ms (  4.94ms)   4.94ms (  4.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 335.00us (  4.65us)  75.35us (  1.05us)        72
#        nlp_g  | 880.00us ( 12.22us) 208.66us (  2.90us)        72
#     nlp_grad  | 120.00us ( 17.14us)  35.13us (  5.02us)         7
#   nlp_grad_f  | 675.00us (  8.44us) 119.35us (  1.49us)        80
#   nlp_hess_l  | 521.00us (  8.14us) 117.21us (  1.83us)        64
#    nlp_jac_g  | 858.00us ( 10.73us) 212.14us (  2.65us)        80
#        total  |   4.90ms (  4.90ms)   4.90ms (  4.90ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 345.00us (  4.31us)  83.32us (  1.04us)        80
#        nlp_g  | 906.00us ( 11.32us) 230.12us (  2.88us)        80
#     nlp_grad  | 124.00us ( 15.50us)  38.65us (  4.83us)         8
#   nlp_grad_f  | 686.00us (  7.71us) 129.97us (  1.46us)        89
#   nlp_hess_l  | 533.00us (  7.51us) 129.06us (  1.82us)        71
#    nlp_jac_g  | 880.00us (  9.89us) 233.66us (  2.63us)        89
#        total  |   4.60ms (  4.60ms)   4.59ms (  4.59ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 354.00us (  4.02us)  91.42us (  1.04us)        88
#        nlp_g  | 929.00us ( 10.56us) 250.53us (  2.85us)        88
#     nlp_grad  | 128.00us ( 14.22us)  42.32us (  4.70us)         9
#   nlp_grad_f  | 698.00us (  7.12us) 140.55us (  1.43us)        98
#   nlp_hess_l  | 548.00us (  7.03us) 140.97us (  1.81us)        78
#    nlp_jac_g  | 901.00us (  9.19us) 255.25us (  2.60us)        98
#        total  |   4.43ms (  4.43ms)   4.43ms (  4.43ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 363.00us (  3.78us)  98.56us (  1.03us)        96
#        nlp_g  | 951.00us (  9.91us) 270.56us (  2.82us)        96
#     nlp_grad  | 132.00us ( 13.20us)  45.84us (  4.58us)        10
#   nlp_grad_f  | 709.00us (  6.63us) 150.82us (  1.41us)       107
#   nlp_hess_l  | 560.00us (  6.59us) 152.63us (  1.80us)        85
#    nlp_jac_g  | 921.00us (  8.61us) 276.36us (  2.58us)       107
#        total  |   4.49ms (  4.49ms)   4.48ms (  4.48ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 371.00us (  3.57us) 106.32us (  1.02us)       104
#        nlp_g  | 977.00us (  9.39us) 292.29us (  2.81us)       104
#     nlp_grad  | 135.00us ( 12.27us)  49.50us (  4.50us)        11
#   nlp_grad_f  | 724.00us (  6.24us) 162.47us (  1.40us)       116
#   nlp_hess_l  | 574.00us (  6.24us) 164.64us (  1.79us)        92
#    nlp_jac_g  | 943.00us (  8.13us) 298.79us (  2.58us)       116
#        total  |   4.65ms (  4.65ms)   4.64ms (  4.64ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 380.00us (  3.39us) 114.00us (  1.02us)       112
#        nlp_g  |   1.00ms (  8.94us) 313.84us (  2.80us)       112
#     nlp_grad  | 139.00us ( 11.58us)  53.21us (  4.43us)        12
#   nlp_grad_f  | 737.00us (  5.90us) 173.20us (  1.39us)       125
#   nlp_hess_l  | 596.00us (  6.02us) 185.67us (  1.88us)        99
#    nlp_jac_g  | 963.00us (  7.70us) 320.83us (  2.57us)       125
#        total  |   4.46ms (  4.46ms)   4.46ms (  4.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 390.00us (  3.25us) 121.40us (  1.01us)       120
#        nlp_g  |   1.03ms (  8.55us) 335.95us (  2.80us)       120
#     nlp_grad  | 144.00us ( 11.08us)  57.80us (  4.45us)        13
#   nlp_grad_f  | 748.00us (  5.58us) 184.42us (  1.38us)       134
#   nlp_hess_l  | 610.00us (  5.75us) 197.65us (  1.86us)       106
#    nlp_jac_g  | 986.00us (  7.36us) 343.89us (  2.57us)       134
#        total  |   4.53ms (  4.53ms)   4.53ms (  4.53ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 400.00us (  3.13us) 129.25us (  1.01us)       128
#        nlp_g  |   1.05ms (  8.24us) 357.90us (  2.80us)       128
#     nlp_grad  | 148.00us ( 10.57us)  61.76us (  4.41us)        14
#   nlp_grad_f  | 760.00us (  5.31us) 195.19us (  1.36us)       143
#   nlp_hess_l  | 624.00us (  5.52us) 209.51us (  1.85us)       113
#    nlp_jac_g  |   1.01ms (  7.06us) 365.56us (  2.56us)       143
#        total  |   4.55ms (  4.55ms)   4.55ms (  4.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 407.00us (  2.99us) 136.98us (  1.01us)       136
#        nlp_g  |   1.08ms (  7.94us) 379.96us (  2.79us)       136
#     nlp_grad  | 152.00us ( 10.13us)  65.32us (  4.35us)        15
#   nlp_grad_f  | 771.00us (  5.07us) 206.11us (  1.36us)       152
#   nlp_hess_l  | 637.00us (  5.31us) 220.87us (  1.84us)       120
#    nlp_jac_g  |   1.03ms (  6.77us) 386.71us (  2.54us)       152
#        total  |   4.42ms (  4.42ms)   4.42ms (  4.42ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 417.00us (  2.90us) 144.67us (  1.00us)       144
#        nlp_g  |   1.10ms (  7.65us) 400.63us (  2.78us)       144
#     nlp_grad  | 156.00us (  9.75us)  68.79us (  4.30us)        16
#   nlp_grad_f  | 782.00us (  4.86us) 216.36us (  1.34us)       161
#   nlp_hess_l  | 651.00us (  5.13us) 232.41us (  1.83us)       127
#    nlp_jac_g  |   1.05ms (  6.52us) 407.92us (  2.53us)       161
#        total  |   4.45ms (  4.45ms)   4.45ms (  4.45ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 426.00us (  2.78us) 152.97us (999.83ns)       153
#        nlp_g  |   1.13ms (  7.39us) 424.68us (  2.78us)       153
#     nlp_grad  | 160.00us (  9.41us)  72.41us (  4.26us)        17
#   nlp_grad_f  | 796.00us (  4.65us) 228.23us (  1.33us)       171
#   nlp_hess_l  | 666.00us (  4.93us) 245.72us (  1.82us)       135
#    nlp_jac_g  |   1.07ms (  6.28us) 432.04us (  2.53us)       171
#        total  |   4.95ms (  4.95ms)   4.95ms (  4.95ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 436.00us (  2.69us) 161.14us (994.68ns)       162
#        nlp_g  |   1.16ms (  7.15us) 448.13us (  2.77us)       162
#     nlp_grad  | 163.00us (  9.06us)  75.97us (  4.22us)        18
#   nlp_grad_f  | 808.00us (  4.46us) 239.94us (  1.33us)       181
#   nlp_hess_l  | 681.00us (  4.76us) 258.74us (  1.81us)       143
#    nlp_jac_g  |   1.10ms (  6.07us) 455.86us (  2.52us)       181
#        total  |   4.98ms (  4.98ms)   4.97ms (  4.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 446.00us (  2.61us) 169.47us (991.04ns)       171
#        nlp_g  |   1.19ms (  6.96us) 473.22us (  2.77us)       171
#     nlp_grad  | 166.00us (  8.74us)  79.42us (  4.18us)        19
#   nlp_grad_f  | 820.00us (  4.29us) 251.80us (  1.32us)       191
#   nlp_hess_l  | 697.00us (  4.62us) 272.47us (  1.80us)       151
#    nlp_jac_g  |   1.12ms (  5.88us) 481.60us (  2.52us)       191
#        total  |   5.19ms (  5.19ms)   5.18ms (  5.18ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 457.00us (  2.54us) 179.03us (994.59ns)       180
#        nlp_g  |   1.24ms (  6.88us) 519.74us (  2.89us)       180
#     nlp_grad  | 170.00us (  8.50us)  83.11us (  4.16us)        20
#   nlp_grad_f  | 833.00us (  4.14us) 263.49us (  1.31us)       201
#   nlp_hess_l  | 711.00us (  4.47us) 285.68us (  1.80us)       159
#    nlp_jac_g  |   1.15ms (  5.72us) 507.84us (  2.53us)       201
#        total  |   5.20ms (  5.20ms)   5.19ms (  5.19ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 469.00us (  2.48us) 187.96us (994.52ns)       189
#        nlp_g  |   1.27ms (  6.70us) 543.72us (  2.88us)       189
#     nlp_grad  | 174.00us (  8.29us)  87.08us (  4.15us)        21
#   nlp_grad_f  | 844.00us (  4.00us) 275.43us (  1.31us)       211
#   nlp_hess_l  | 726.00us (  4.35us) 299.69us (  1.79us)       167
#    nlp_jac_g  |   1.18ms (  5.57us) 533.34us (  2.53us)       211
#        total  |   4.97ms (  4.97ms)   4.97ms (  4.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 483.00us (  2.44us) 197.69us (998.42ns)       198
#        nlp_g  |   1.30ms (  6.56us) 569.33us (  2.88us)       198
#     nlp_grad  | 178.00us (  8.09us)  90.84us (  4.13us)        22
#   nlp_grad_f  | 858.00us (  3.88us) 288.23us (  1.30us)       221
#   nlp_hess_l  | 740.00us (  4.23us) 313.60us (  1.79us)       175
#    nlp_jac_g  |   1.20ms (  5.44us) 558.16us (  2.53us)       221
#        total  |   5.20ms (  5.20ms)   5.19ms (  5.19ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 492.00us (  2.38us) 206.56us (997.88ns)       207
#        nlp_g  |   1.33ms (  6.42us) 594.24us (  2.87us)       207
#     nlp_grad  | 182.00us (  7.91us)  94.60us (  4.11us)        23
#   nlp_grad_f  | 871.00us (  3.77us) 300.62us (  1.30us)       231
#   nlp_hess_l  | 756.00us (  4.13us) 327.29us (  1.79us)       183
#    nlp_jac_g  |   1.23ms (  5.31us) 582.87us (  2.52us)       231
#        total  |   4.94ms (  4.94ms)   4.94ms (  4.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 501.00us (  2.32us) 215.14us (996.03ns)       216
#        nlp_g  |   1.36ms (  6.30us) 618.94us (  2.87us)       216
#     nlp_grad  | 186.00us (  7.75us)  98.18us (  4.09us)        24
#   nlp_grad_f  | 886.00us (  3.68us) 313.35us (  1.30us)       241
#   nlp_hess_l  | 771.00us (  4.04us) 340.59us (  1.78us)       191
#    nlp_jac_g  |   1.25ms (  5.19us) 609.11us (  2.53us)       241
#        total  |   5.03ms (  5.03ms)   5.02ms (  5.02ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 512.00us (  2.28us) 224.16us (996.25ns)       225
#        nlp_g  |   1.39ms (  6.17us) 643.01us (  2.86us)       225
#     nlp_grad  | 191.00us (  7.64us) 102.84us (  4.11us)        25
#   nlp_grad_f  | 900.00us (  3.59us) 325.51us (  1.30us)       251
#   nlp_hess_l  | 785.00us (  3.94us) 353.91us (  1.78us)       199
#    nlp_jac_g  |   1.27ms (  5.08us) 635.07us (  2.53us)       251
#        total  |   5.07ms (  5.07ms)   5.06ms (  5.06ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 522.00us (  2.23us) 232.34us (992.88ns)       234
#        nlp_g  |   1.41ms (  6.04us) 665.64us (  2.84us)       234
#     nlp_grad  | 195.00us (  7.50us) 106.74us (  4.11us)        26
#   nlp_grad_f  | 912.00us (  3.49us) 336.97us (  1.29us)       261
#   nlp_hess_l  | 801.00us (  3.87us) 367.26us (  1.77us)       207
#    nlp_jac_g  |   1.30ms (  4.97us) 659.75us (  2.53us)       261
#        total  |   4.85ms (  4.85ms)   4.85ms (  4.85ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 533.00us (  2.19us) 241.38us (993.35ns)       243
#        nlp_g  |   1.44ms (  5.94us) 690.38us (  2.84us)       243
#     nlp_grad  | 198.00us (  7.33us) 110.35us (  4.09us)        27
#   nlp_grad_f  | 925.00us (  3.41us) 348.53us (  1.29us)       271
#   nlp_hess_l  | 829.00us (  3.86us) 394.59us (  1.84us)       215
#    nlp_jac_g  |   1.32ms (  4.86us) 684.16us (  2.52us)       271
#        total  |   5.42ms (  5.42ms)   5.42ms (  5.42ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 545.00us (  2.16us) 250.63us (994.58ns)       252
#        nlp_g  |   1.47ms (  5.83us) 713.09us (  2.83us)       252
#     nlp_grad  | 202.00us (  7.21us) 113.90us (  4.07us)        28
#   nlp_grad_f  | 937.00us (  3.33us) 359.82us (  1.28us)       281
#   nlp_hess_l  | 844.00us (  3.78us) 407.70us (  1.83us)       223
#    nlp_jac_g  |   1.34ms (  4.78us) 708.83us (  2.52us)       281
#        total  |   4.88ms (  4.88ms)   4.88ms (  4.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 552.00us (  2.11us) 258.88us (991.87ns)       261
#        nlp_g  |   1.50ms (  5.74us) 736.04us (  2.82us)       261
#     nlp_grad  | 206.00us (  7.10us) 117.62us (  4.06us)        29
#   nlp_grad_f  | 950.00us (  3.26us) 371.29us (  1.28us)       291
#   nlp_hess_l  | 857.00us (  3.71us) 420.93us (  1.82us)       231
#    nlp_jac_g  |   1.37ms (  4.70us) 734.09us (  2.52us)       291
#        total  |   4.99ms (  4.99ms)   4.98ms (  4.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 563.00us (  2.08us) 268.28us (989.97ns)       271
#        nlp_g  |   1.53ms (  5.65us) 763.35us (  2.82us)       271
#     nlp_grad  | 210.00us (  7.00us) 121.31us (  4.04us)        30
#   nlp_grad_f  | 965.00us (  3.20us) 384.73us (  1.27us)       302
#   nlp_hess_l  | 875.00us (  3.65us) 436.15us (  1.82us)       240
#    nlp_jac_g  |   1.40ms (  4.63us) 762.56us (  2.53us)       302
#        total  |   5.63ms (  5.63ms)   5.63ms (  5.63ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 573.00us (  2.04us) 277.34us (986.96ns)       281
#        nlp_g  |   1.56ms (  5.56us) 789.88us (  2.81us)       281
#     nlp_grad  | 213.00us (  6.87us) 125.08us (  4.03us)        31
#   nlp_grad_f  | 979.00us (  3.13us) 397.28us (  1.27us)       313
#   nlp_hess_l  | 889.00us (  3.57us) 450.77us (  1.81us)       249
#    nlp_jac_g  |   1.42ms (  4.55us) 791.07us (  2.53us)       313
#        total  |   5.49ms (  5.49ms)   5.48ms (  5.48ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 587.00us (  2.02us) 287.89us (989.30ns)       291
#        nlp_g  |   1.60ms (  5.48us) 817.65us (  2.81us)       291
#     nlp_grad  | 216.00us (  6.75us) 128.80us (  4.03us)        32
#   nlp_grad_f  | 994.00us (  3.07us) 410.64us (  1.27us)       324
#   nlp_hess_l  | 907.00us (  3.52us) 465.31us (  1.80us)       258
#    nlp_jac_g  |   1.45ms (  4.47us) 818.66us (  2.53us)       324
#        total  |   5.52ms (  5.52ms)   5.51ms (  5.51ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 598.00us (  1.99us) 297.57us (988.59ns)       301
#        nlp_g  |   1.63ms (  5.42us) 845.15us (  2.81us)       301
#     nlp_grad  | 219.00us (  6.64us) 132.42us (  4.01us)        33
#   nlp_grad_f  |   1.01ms (  3.01us) 424.02us (  1.27us)       335
#   nlp_hess_l  | 923.00us (  3.46us) 480.63us (  1.80us)       267
#    nlp_jac_g  |   1.47ms (  4.40us) 847.06us (  2.53us)       335
#        total  |   5.82ms (  5.82ms)   5.81ms (  5.81ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 608.00us (  1.95us) 307.80us (986.54ns)       312
#        nlp_g  |   1.67ms (  5.34us) 874.48us (  2.80us)       312
#     nlp_grad  | 223.00us (  6.56us) 136.01us (  4.00us)        34
#   nlp_grad_f  |   1.02ms (  2.95us) 438.32us (  1.26us)       347
#   nlp_hess_l  | 941.00us (  3.40us) 498.07us (  1.80us)       277
#    nlp_jac_g  |   1.50ms (  4.33us) 876.21us (  2.53us)       347
#        total  |   5.91ms (  5.91ms)   5.91ms (  5.91ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 619.00us (  1.92us) 318.01us (987.59ns)       322
#        nlp_g  |   1.70ms (  5.28us) 902.24us (  2.80us)       322
#     nlp_grad  | 226.00us (  6.46us) 139.67us (  3.99us)        35
#   nlp_grad_f  |   1.04ms (  2.90us) 451.62us (  1.26us)       358
#   nlp_hess_l  | 958.00us (  3.35us) 513.55us (  1.80us)       286
#    nlp_jac_g  |   1.53ms (  4.27us) 904.35us (  2.53us)       358
#        total  |   6.15ms (  6.15ms)   6.14ms (  6.14ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 629.00us (  1.91us) 325.98us (987.81ns)       330
#        nlp_g  |   1.73ms (  5.23us) 923.13us (  2.80us)       330
#     nlp_grad  | 232.00us (  6.44us) 145.19us (  4.03us)        36
#   nlp_grad_f  |   1.05ms (  2.86us) 462.16us (  1.26us)       367
#   nlp_hess_l  | 971.00us (  3.31us) 525.11us (  1.79us)       293
#    nlp_jac_g  |   1.55ms (  4.22us) 925.85us (  2.52us)       367
#        total  |   4.43ms (  4.43ms)   4.43ms (  4.43ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 639.00us (  1.89us) 334.10us (988.46ns)       338
#        nlp_g  |   1.75ms (  5.18us) 944.20us (  2.79us)       338
#     nlp_grad  | 236.00us (  6.38us) 149.14us (  4.03us)        37
#   nlp_grad_f  |   1.06ms (  2.82us) 473.20us (  1.26us)       376
#   nlp_hess_l  | 982.00us (  3.27us) 536.84us (  1.79us)       300
#    nlp_jac_g  |   1.57ms (  4.17us) 947.10us (  2.52us)       376
#        total  |   4.51ms (  4.51ms)   4.51ms (  4.51ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 649.00us (  1.88us) 342.06us (988.62ns)       346
#        nlp_g  |   1.78ms (  5.13us) 965.98us (  2.79us)       346
#     nlp_grad  | 240.00us (  6.32us) 152.84us (  4.02us)        38
#   nlp_grad_f  |   1.07ms (  2.78us) 484.04us (  1.26us)       385
#   nlp_hess_l  | 995.00us (  3.24us) 549.29us (  1.79us)       307
#    nlp_jac_g  |   1.59ms (  4.13us) 969.76us (  2.52us)       385
#        total  |   4.88ms (  4.88ms)   4.87ms (  4.87ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 658.00us (  1.86us) 348.95us (988.53ns)       353
#        nlp_g  |   1.80ms (  5.09us) 984.65us (  2.79us)       353
#     nlp_grad  | 244.00us (  6.26us) 156.99us (  4.03us)        39
#   nlp_grad_f  |   1.08ms (  2.76us) 493.56us (  1.26us)       393
#   nlp_hess_l  |   1.01ms (  3.21us) 559.30us (  1.79us)       313
#    nlp_jac_g  |   1.61ms (  4.09us) 988.89us (  2.52us)       393
#        total  |   4.04ms (  4.04ms)   4.04ms (  4.04ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 669.00us (  1.85us) 357.62us (990.64ns)       361
#        nlp_g  |   1.83ms (  5.07us)   1.01ms (  2.79us)       361
#     nlp_grad  | 248.00us (  6.20us) 161.45us (  4.04us)        40
#   nlp_grad_f  |   1.11ms (  2.77us) 523.49us (  1.30us)       402
#   nlp_hess_l  |   1.02ms (  3.18us) 571.38us (  1.79us)       320
#    nlp_jac_g  |   1.63ms (  4.06us)   1.01ms (  2.52us)       402
#        total  |   5.04ms (  5.04ms)   5.03ms (  5.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 679.00us (  1.84us) 366.03us (989.26ns)       370
#        nlp_g  |   1.86ms (  5.02us)   1.03ms (  2.79us)       370
#     nlp_grad  | 251.00us (  6.12us) 165.20us (  4.03us)        41
#   nlp_grad_f  |   1.13ms (  2.74us) 535.44us (  1.30us)       412
#   nlp_hess_l  |   1.03ms (  3.14us) 584.47us (  1.78us)       328
#    nlp_jac_g  |   1.66ms (  4.02us)   1.04ms (  2.52us)       412
#        total  |   4.92ms (  4.92ms)   4.92ms (  4.92ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 689.00us (  1.82us) 374.39us (987.85ns)       379
#        nlp_g  |   1.89ms (  4.99us)   1.06ms (  2.79us)       379
#     nlp_grad  | 255.00us (  6.07us) 169.76us (  4.04us)        42
#   nlp_grad_f  |   1.14ms (  2.71us) 547.89us (  1.30us)       422
#   nlp_hess_l  |   1.05ms (  3.11us) 598.22us (  1.78us)       336
#    nlp_jac_g  |   1.68ms (  3.98us)   1.06ms (  2.52us)       422
#        total  |   5.27ms (  5.27ms)   5.26ms (  5.26ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 700.00us (  1.80us) 384.42us (988.21ns)       389
#        nlp_g  |   1.93ms (  4.95us)   1.08ms (  2.79us)       389
#     nlp_grad  | 259.00us (  6.02us) 173.42us (  4.03us)        43
#   nlp_grad_f  |   1.16ms (  2.68us) 561.89us (  1.30us)       433
#   nlp_hess_l  |   1.06ms (  3.08us) 613.58us (  1.78us)       345
#    nlp_jac_g  |   1.71ms (  3.95us)   1.09ms (  2.53us)       433
#        total  |   6.98ms (  6.98ms)   5.71ms (  5.71ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 709.00us (  1.78us) 393.33us (985.78ns)       399
#        nlp_g  |   1.96ms (  4.91us)   1.11ms (  2.78us)       399
#     nlp_grad  | 263.00us (  5.98us) 177.07us (  4.02us)        44
#   nlp_grad_f  |   1.17ms (  2.64us) 574.51us (  1.29us)       444
#   nlp_hess_l  |   1.08ms (  3.04us) 628.56us (  1.78us)       354
#    nlp_jac_g  |   1.74ms (  3.92us)   1.12ms (  2.53us)       444
#        total  |   5.39ms (  5.39ms)   5.38ms (  5.38ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 718.00us (  1.76us) 402.32us (983.67ns)       409
#        nlp_g  |   1.99ms (  4.87us)   1.14ms (  2.78us)       409
#     nlp_grad  | 266.00us (  5.91us) 180.57us (  4.01us)        45
#   nlp_grad_f  |   1.18ms (  2.60us) 587.61us (  1.29us)       455
#   nlp_hess_l  |   1.09ms (  3.01us) 643.93us (  1.77us)       363
#    nlp_jac_g  |   1.77ms (  3.89us)   1.15ms (  2.53us)       455
#        total  |   5.44ms (  5.44ms)   5.44ms (  5.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 728.00us (  1.73us) 412.24us (981.52ns)       420
#        nlp_g  |   2.03ms (  4.83us)   1.17ms (  2.78us)       420
#     nlp_grad  | 270.00us (  5.87us) 184.18us (  4.00us)        46
#   nlp_grad_f  |   1.20ms (  2.57us) 601.50us (  1.29us)       467
#   nlp_hess_l  |   1.11ms (  2.98us) 660.30us (  1.77us)       373
#    nlp_jac_g  |   1.80ms (  3.86us)   1.18ms (  2.53us)       467
#        total  |   6.02ms (  6.02ms)   6.01ms (  6.01ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 739.00us (  1.71us) 422.38us (980.00ns)       431
#        nlp_g  |   2.07ms (  4.79us)   1.20ms (  2.78us)       431
#     nlp_grad  | 275.00us (  5.85us) 189.19us (  4.03us)        47
#   nlp_grad_f  |   1.21ms (  2.54us) 615.51us (  1.28us)       479
#   nlp_hess_l  |   1.13ms (  2.96us) 676.94us (  1.77us)       383
#    nlp_jac_g  |   1.83ms (  3.82us)   1.21ms (  2.53us)       479
#        total  |   5.98ms (  5.98ms)   5.98ms (  5.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 752.00us (  1.70us) 433.47us (978.49ns)       443
#        nlp_g  |   2.11ms (  4.76us)   1.23ms (  2.78us)       443
#     nlp_grad  | 279.00us (  5.81us) 192.76us (  4.02us)        48
#   nlp_grad_f  |   1.24ms (  2.51us) 632.15us (  1.28us)       492
#   nlp_hess_l  |   1.15ms (  2.93us) 696.71us (  1.77us)       394
#    nlp_jac_g  |   1.87ms (  3.79us)   1.24ms (  2.53us)       492
#        total  |   6.76ms (  6.76ms)   6.75ms (  6.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 765.00us (  1.68us) 444.31us (976.51ns)       455
#        nlp_g  |   2.14ms (  4.71us)   1.26ms (  2.78us)       455
#     nlp_grad  | 283.00us (  5.78us) 196.53us (  4.01us)        49
#   nlp_grad_f  |   1.25ms (  2.48us) 647.02us (  1.28us)       505
#   nlp_hess_l  |   1.17ms (  2.89us) 715.06us (  1.77us)       405
#    nlp_jac_g  |   1.90ms (  3.76us)   1.28ms (  2.53us)       505
#        total  |   6.33ms (  6.33ms)   6.33ms (  6.33ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 778.00us (  1.66us) 456.17us (974.72ns)       468
#        nlp_g  |   2.19ms (  4.67us)   1.30ms (  2.77us)       468
#     nlp_grad  | 286.00us (  5.72us) 200.21us (  4.00us)        50
#   nlp_grad_f  |   1.27ms (  2.45us) 663.11us (  1.28us)       519
#   nlp_hess_l  |   1.19ms (  2.86us) 735.11us (  1.76us)       417
#    nlp_jac_g  |   1.94ms (  3.73us)   1.31ms (  2.53us)       519
#        total  |   7.08ms (  7.08ms)   7.08ms (  7.08ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 791.00us (  1.65us) 467.09us (973.11ns)       480
#        nlp_g  |   2.22ms (  4.63us)   1.33ms (  2.77us)       480
#     nlp_grad  | 289.00us (  5.67us) 203.69us (  3.99us)        51
#   nlp_grad_f  |   1.29ms (  2.42us) 678.12us (  1.27us)       532
#   nlp_hess_l  |   1.21ms (  2.84us) 753.56us (  1.76us)       428
#    nlp_jac_g  |   1.97ms (  3.70us)   1.35ms (  2.53us)       532
#        total  |   6.52ms (  6.52ms)   6.51ms (  6.51ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 806.00us (  1.63us) 480.30us (972.28ns)       494
#        nlp_g  |   2.27ms (  4.59us)   1.37ms (  2.77us)       494
#     nlp_grad  | 293.00us (  5.63us) 207.33us (  3.99us)        52
#   nlp_grad_f  |   1.31ms (  2.39us) 695.33us (  1.27us)       547
#   nlp_hess_l  |   1.24ms (  2.80us) 775.08us (  1.76us)       441
#    nlp_jac_g  |   2.01ms (  3.67us)   1.38ms (  2.53us)       547
#        total  |   7.67ms (  7.67ms)   7.66ms (  7.66ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 821.00us (  1.62us) 493.20us (970.86ns)       508
#        nlp_g  |   2.31ms (  4.55us)   1.41ms (  2.77us)       508
#     nlp_grad  | 296.00us (  5.58us) 210.91us (  3.98us)        53
#   nlp_grad_f  |   1.32ms (  2.36us) 712.54us (  1.27us)       562
#   nlp_hess_l  |   1.26ms (  2.78us) 796.62us (  1.75us)       454
#    nlp_jac_g  |   2.04ms (  3.63us)   1.42ms (  2.53us)       562
#        total  |   7.25ms (  7.25ms)   7.25ms (  7.25ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 836.00us (  1.60us) 506.13us (969.59ns)       522
#        nlp_g  |   2.36ms (  4.52us)   1.44ms (  2.77us)       522
#     nlp_grad  | 300.00us (  5.56us) 214.65us (  3.97us)        54
#   nlp_grad_f  |   1.34ms (  2.33us) 729.31us (  1.26us)       577
#   nlp_hess_l  |   1.28ms (  2.75us) 817.81us (  1.75us)       467
#    nlp_jac_g  |   2.08ms (  3.60us)   1.46ms (  2.53us)       577
#        total  |   7.40ms (  7.40ms)   7.39ms (  7.39ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 852.00us (  1.59us) 519.39us (969.00ns)       536
#        nlp_g  |   2.40ms (  4.48us)   1.48ms (  2.77us)       536
#     nlp_grad  | 304.00us (  5.53us) 218.31us (  3.97us)        55
#   nlp_grad_f  |   1.36ms (  2.30us) 746.49us (  1.26us)       592
#   nlp_hess_l  |   1.31ms (  2.73us) 840.14us (  1.75us)       480
#    nlp_jac_g  |   2.11ms (  3.57us)   1.50ms (  2.53us)       592
#        total  |   7.46ms (  7.46ms)   7.46ms (  7.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 868.00us (  1.57us) 533.80us (967.03ns)       552
#        nlp_g  |   2.46ms (  4.45us)   1.53ms (  2.76us)       552
#     nlp_grad  | 307.00us (  5.48us) 221.84us (  3.96us)        56
#   nlp_grad_f  |   1.38ms (  2.28us) 764.94us (  1.26us)       608
#   nlp_hess_l  |   1.35ms (  2.74us) 881.63us (  1.78us)       494
#    nlp_jac_g  |   2.15ms (  3.54us)   1.54ms (  2.52us)       608
#        total  |   8.10ms (  8.10ms)   8.09ms (  8.09ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 885.00us (  1.56us) 548.31us (965.33ns)       568
#        nlp_g  |   2.51ms (  4.42us)   1.57ms (  2.76us)       568
#     nlp_grad  | 310.00us (  5.44us) 225.45us (  3.96us)        57
#   nlp_grad_f  |   1.40ms (  2.25us) 782.72us (  1.25us)       624
#   nlp_hess_l  |   1.38ms (  2.71us) 904.80us (  1.78us)       508
#    nlp_jac_g  |   2.19ms (  3.51us)   1.57ms (  2.52us)       624
#        total  |   8.10ms (  8.10ms)   8.09ms (  8.09ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 901.00us (  1.55us) 561.33us (964.49ns)       582
#        nlp_g  |   2.56ms (  4.39us)   1.61ms (  2.76us)       582
#     nlp_grad  | 315.00us (  5.43us) 229.84us (  3.96us)        58
#   nlp_grad_f  |   1.42ms (  2.22us) 801.07us (  1.25us)       639
#   nlp_hess_l  |   1.40ms (  2.69us) 926.00us (  1.78us)       521
#    nlp_jac_g  |   2.23ms (  3.49us)   1.61ms (  2.52us)       639
#        total  |   7.50ms (  7.50ms)   7.49ms (  7.49ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 916.00us (  1.54us) 573.92us (962.95ns)       596
#        nlp_g  |   2.60ms (  4.37us)   1.64ms (  2.76us)       596
#     nlp_grad  | 319.00us (  5.41us) 233.51us (  3.96us)        59
#   nlp_grad_f  |   1.44ms (  2.21us) 820.28us (  1.25us)       654
#   nlp_hess_l  |   1.42ms (  2.66us) 947.46us (  1.77us)       534
#    nlp_jac_g  |   2.26ms (  3.46us)   1.65ms (  2.52us)       654
#        total  |   7.53ms (  7.53ms)   7.52ms (  7.52ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 933.00us (  1.53us) 589.19us (965.88ns)       610
#        nlp_g  |   2.66ms (  4.36us)   1.69ms (  2.77us)       610
#     nlp_grad  | 323.00us (  5.38us) 237.32us (  3.96us)        60
#   nlp_grad_f  |   1.46ms (  2.19us) 839.47us (  1.25us)       669
#   nlp_hess_l  |   1.45ms (  2.65us) 973.52us (  1.78us)       547
#    nlp_jac_g  |   2.32ms (  3.47us)   1.71ms (  2.55us)       669
#        total  |   8.86ms (  8.86ms)   8.85ms (  8.85ms)         1

# %% [markdown]
# ### Plotting

# %% [markdown]
# State and input profiles of closed-loop experiments for a single iteration
#
# States  X (CEM, Ts)
#
# Control U (P  , q )

# %%
x_axis = np.arange(Ns + 1)
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, figsize=(7, 15))   

# State 1
ax1.plot(np.arange(Ns + 1), np.ravel(X_sim[0]) + yss[0], label='Actual')
ax1.plot(np.arange(Ns + 1), np.ravel(X_est[0]) + yss[0], label='Est.')
ax1.set_ylabel('Surface temperature [$^\circ$C]')
ax1.legend(loc='lower right')

# State 2
ax3.plot(np.arange(Ns + 1), np.ravel(X_sim[2]) + yss[1], label='Actual')
ax3.plot(np.arange(Ns + 1), np.ravel(X_est[2]) + yss[1], label='Est.')
ax3.set_ylabel('Intensity I [a.u.]')
ax3.legend()

ax2.plot(x_axis, np.ravel(X_sim[1]), label='actual')
ax2.plot(x_axis, np.ravel(X_est[1]), label='est.')
ax2.set_ylabel('')

ax4.plot(x_axis, np.ravel(X_sim[3]), label='actual')
ax4.plot(x_axis, np.ravel(X_est[3]), label='est.')
ax4.set_ylabel('')

ax5.plot(x_axis, np.ravel(X_sim[4]), label='actual')
ax5.plot(x_axis, np.ravel(X_est[4]), label='est.')
ax5.set_ylabel('')

ax5.set_xlabel('Time [s]')
plt.tight_layout()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 5)) 

# # CEM
# ax1.plot(np.arange(CEMsim.shape[1]), np.ravel(CEMsim))
# ax1.axhline([1.5], linestyle='--', color='black', label='Target reference')
# ax1.set_ylabel('CEM [min]')
# ax1.legend()

# Ts
ax1.plot(np.arange(Y_sim[0].shape[0]), np.ravel(Y_sim[0]) + yss[0])
ax1.axhline([45.], color='red', linestyle='--', label='Max temperature', alpha=0.5)
ax1.set_ylabel('Surface temperature [$^\circ$C]')
ax1.legend()
# I
ax2.plot(np.arange(Y_sim[1].shape[0]), np.ravel(Y_sim[1]) + yss[1])
ax2.set_ylabel('I [a.u.]')
# P
ax3.step(np.arange(U_sim[0].shape[0]), np.ravel(U_sim[0]) + uss[0])
ax3.axhline([u_max[0] + uss[0]], color='r', alpha=0.5)
ax3.axhline([u_min[0] + uss[0]], color='r', alpha=0.5)
ax3.set_ylabel('Power [W]')
ax3.set_xlabel('Time [s]')
# q
ax4.step(np.arange(U_sim[1].shape[0]), np.ravel(U_sim[1]) + uss[1])
ax4.axhline([u_max[1] + uss[1]], color='r', alpha=0.5)
ax4.axhline([u_min[1] + uss[1]], color='r', alpha=0.5)
ax4.set_ylabel('Flow rate [SLM]')
ax4.set_xlabel('Time [s]')

plt.tight_layout()
